# %%
import example_project_with_rye.util.llm as llmp

llmp.ask_a_pirate_about_life()
# Out:
# <class 'openai.types.chat.chat_completion.ChatCompletion'>
# id: chatcmpl-9ssDHtU7nxMS2LYW9AcidviBZIfXW
# choices:
# - finish_reason: stop
#   index: 0
#   logprobs:
#   message: {content: "Ahoy, matey! The purpose o' life be a question as deep as the
#       seven seas. Fer some, it be seekin' adventure and treasure, fer others, it be
#       findin' love and camaraderie among their crew. Some might say it be about discoverin'
#       yer own path and makin' yer mark on the world, like a true buccaneer. In the
#       end, it be a journey, and each pirate must chart their own course. Arrr!", role: assistant,
#     function_call: null, tool_calls: null}
#   content_filter_results:
#     hate: {filtered: false, severity: safe}
#     self_harm: {filtered: false, severity: safe}
#     sexual: {filtered: false, severity: safe}
#     violence: {filtered: false, severity: safe}
# created: 1722865135
# model: gpt-4o-2024-05-13
# object: chat.completion
# service_tier:
# ...
